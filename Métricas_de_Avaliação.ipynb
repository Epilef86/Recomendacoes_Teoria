# %% [markdown]
# <a href="https://colab.research.google.com/github/Epilef86/Recomendacoes_/blob/main/M%C3%A9tricas_de_Avalia%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vamos falar de 03 métricas de acuária:

# %% [markdown]
# O 1º tipo de métrica:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Verifica quanto que se está acertando do feedback que o usuário vai dar pra um determinado item.

# %% [markdown]
# Podemos determinar uma variável de erro Eui que nada mais é que qual foi a nota que um determinado usuário deu pra um item menos o que foi estimado pra aquela nota. Então é uma métrica de erro entre o target e o predition

# %% [markdown]
# Quando se trabalha com métricas de acurácia a gente só quer trabalhar na previsão do que a gente conhece, das entradas dos usuários.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As outras métricas que também são bem utilizadas:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Essas métricas têm alguns problemas:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O 2º tipo de métrica:

# %% [markdown]
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# Conseguimos ver o problema de recomendação também como um problema de classificação. Imagina que eu quero classificar se o usuário vai ou não consumir um determinado tipo de item, nesse sentido podemos criar uma tabela verdade.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# E ai dentro dessas métricas de classificação conseguimos usar precisão e recall

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A precisão e o recall são métricas que consideram o tamanho da lista recomendada, por isso colocar precision@K aonde K é o tamanho da lista recomendada. Ou seja, se tivermos um tamanho da lista de 20, iremos falar precision@20. Essas métricas também têm alguns problemas:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ou seja, não conseguimos utilizar essas métricas como forma de otimização dos algoritmos

# %% [markdown]
# Um exemplo da acurácia de classificação:

# %% [markdown]
# Imagina que temos esse catálogo representados pelas caixas coloridas, vamos falar que o usuário consumiu dois itens, o azul e o amarelo mas na verdade foi recomendado 03 itens: amarelo, preto e verde.

# %% [markdown]
# Como vai ser o truepositive? só vai ser o item amarelo entção o TP = 1;
#
# FP foi recomendado o preto e o verde mas o usuário não consumiu esses itens, então FP = 2;
#
# FN consumiu e não foi recomendado FN = 1, item azul

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O 3º tipo de métrica:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aonde utiliza o ranku , se o usuário consumiu o 1º item da lista essa variável vai estar com 1, se consumiu o 10º item da lista vai estar como 10.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Podemos definir o MRR@K, que é uma métrica bem utilizada em motores de busca em que queremos saber a partir da recomendação que fizemos na busca qual dos itens da lista ordenada o usuário consumiu ou o usuário clicou.

# %% [markdown]
# Essa métrica leva em consideração: média dos usuários e qual foi o ranking do item consumido pelo usuário. Quanto menor o ranking maior vai ser essa métrica

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Um problema dessa métrica:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ou seja, essa métrica não consegue ser utilizada como parâmetro de otimização direto em alguns algoritmos que conseguem treinar a partir de uma derivação de métrica.

# %% [markdown]
# Um exemplo:

# %% [markdown]
# Vamos supor que tenha recomendado esses 04 itens. O usuário 1 consumiu primeiro item, o usuário dois consumiu o quarto item.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O MRR@4 vai ser o valor invertido desses ranks. O |U| é o número de usuários que estamos considerando
